# %%
import gym
import numpy as np
import random
import math
from time import sleep


## Initialize the "Cart-Pole" environment
env = gym.make('CartPole-v0')

## Defining the environment related constants

# Number of discrete states (bucket) per state dimension
NUM_BUCKETS = (1, 1, 6, 3)  # (x, x', theta, theta')
# Number of discrete actions
NUM_ACTIONS = env.action_space.n # (left, right)
# Bounds for each discrete state
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))
STATE_BOUNDS[1] = [-0.5, 0.5]
STATE_BOUNDS[3] = [-math.radians(50), math.radians(50)]
# Index of the action
ACTION_INDEX = len(NUM_BUCKETS)

## Creating a Q-Table for each state-action pair
q_table = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,))

## Learning related constants
MIN_EXPLORE_RATE = 0.01
MIN_LEARNING_RATE = 0.1

## Defining the simulation related constants
NUM_EPISODES = 1000
MAX_T = 250
STREAK_TO_END = 120
SOLVED_T = 199
DEBUG_MODE = True

def simulate():

    ## Instantiating the learning related parameters
    learning_rate = get_learning_rate(0)
    explore_rate = get_explore_rate(0)
    discount_factor = 0.99  # since the world is unchanging

    num_streaks = 0

    for episode in range(NUM_EPISODES):

        # Reset the environment
        obv = env.reset()

        # the initial state
        state_0 = state_to_bucket(obv)

        for t in range(MAX_T):
            # env.render()

            # Select an action
            action = select_action(state_0, explore_rate)

            # Execute the action
            obv, reward, done, _ = env.step(action)

            # Observe the result
            state = state_to_bucket(obv)

            # Update the Q based on the result
            best_q = np.amax(q_table[state])
            q_table[state_0 + (action,)] += learning_rate*(reward + discount_factor*(best_q) - q_table[state_0 + (action,)])

            # Setting up for the next iteration
            state_0 = state

            # Print data
            if (DEBUG_MODE):
                print("\nEpisode = %d" % episode)
                print("t = %d" % t)
                print("Action: %d" % action)
                print("State: %s" % str(state))
                print("Reward: %f" % reward)
                print("Best Q: %f" % best_q)
                print("Explore rate: %f" % explore_rate)
                print("Learning rate: %f" % learning_rate)
                print("Streaks: %d" % num_streaks)

                print("")

            if done:
               print("Episode %d finished after %f time steps" % (episode, t))
               if (t >= SOLVED_T):
                   num_streaks += 1
               else:
                   num_streaks = 0
               break

            #sleep(0.25)

        # It's considered done when it's solved over 120 times consecutively
        if num_streaks > STREAK_TO_END:
            break

        # Update parameters
        explore_rate = get_explore_rate(episode)
        learning_rate = get_learning_rate(episode)


def select_action(state, explore_rate):
    # Select a random action
    if random.random() < explore_rate:
        action = env.action_space.sample()
    # Select the action with the highest q
    else:
        action = np.argmax(q_table[state])
    return action


def get_explore_rate(t):
    return max(MIN_EXPLORE_RATE, min(1, 1.0 - math.log10((t+1)/25)))

def get_learning_rate(t):
    return max(MIN_LEARNING_RATE, min(0.5, 1.0 - math.log10((t+1)/25)))

def state_to_bucket(state):
    bucket_indice = []
    for i in range(len(state)):
        if state[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif state[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_BUCKETS[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_BUCKETS[i]-1)*STATE_BOUNDS[i][0]/bound_width
            scaling = (NUM_BUCKETS[i]-1)/bound_width
            bucket_index = int(round(scaling*state[i] - offset))
        bucket_indice.append(bucket_index)
    return tuple(bucket_indice)

if __name__ == "__main__":
    simulate()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#
# Episode = 0
# t = 0
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 1
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 0.500000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 2
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 0.747500
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 3
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 1.243763
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 4
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 1.365662
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 5
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 6
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 7
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 0.500000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 8
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 9
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 10
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 0.500000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 11
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 0.997500
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 12
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 0.997500
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 13
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 14
# Action: 0
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 0 finished after 14.000000 time steps
#
# Episode = 1
# t = 0
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 1
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 2
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 3
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 0.500000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 4
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 5
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 6
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 0.500000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 7
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 0.747500
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 8
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 1.243763
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 9
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 1.365662
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 10
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 1.858834
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 11
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 2.042004
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 12
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 1.398942
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 13
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 1.398942
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 14
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 2.458373
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 15
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 2.399726
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 16
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 2.917051
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 17
# Action: 1
# State: (0, 0, 4, 1)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 18
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 19
# Action: 1
# State: (0, 0, 4, 1)
# Reward: 1.000000
# Best Q: 0.500000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 20
# Action: 1
# State: (0, 0, 4, 1)
# Reward: 1.000000
# Best Q: 0.500000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 21
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 0.747500
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 22
# Action: 1
# State: (0, 0, 4, 1)
# Reward: 1.000000
# Best Q: 1.120013
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 9.565939
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 2
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 9.885162
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 3
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 8.775040
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 4
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 10.011513
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 5
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 10.011513
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 6
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 10.238668
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 7
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 9.843219
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 8
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 10.664764
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 9
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 10.664764
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 10
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 10.664764
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 11
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 10.664764
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 12
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 11.111440
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 13
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 11.191047
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 14
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 11.595288
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 15
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 3.144672
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 16
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 3.144672
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 17
# Action: 1
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 3.510115
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 9 finished after 17.000000 time steps
#
# Episode = 10
# t = 0
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 10.659342
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 1
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 6.768928
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 2
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 10.659342
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 3
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 10.659342
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 4
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 11.106045
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 5
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 8.922525
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 6
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 8.922525
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 7
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 8.922525
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 8
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 9.067207
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 9
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 9.449530
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 10
# Action: 0
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 1.614412
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 11
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 1.614412
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 12
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 1.672884
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 10 finished after 12.000000 time steps
#
# Episode = 11
# t = 0
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 11.106045
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 1
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 11.550515
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 2
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 13.793152
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 3
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 11.595288
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 4
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 13.793152
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 5
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 13.125254
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 6
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 13.793152
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 7
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 13.793152
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 8
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 14.224186
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 9
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 4.350940
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 10
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 12.911010
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 11
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 12.911010
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 12
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 13.346455
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 13
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 13.779723
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 14
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 13.779723
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 15
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 9.066420
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 16
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 13.779723
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 17
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 11.854173
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 18
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 11.854173
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 19
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 9.067207
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 20
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 9.067207
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 21
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 9.521871
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 22
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 9.521871
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 23
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 9.521871
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 24
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 9.974262
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 25
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 10.424390
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 26
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 10.424390
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 27
# Action: 0
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 2.164520
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 28
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 2.164520
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 29
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 2.653697
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 30
# Action: 0
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 3.140429
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 11 finished after 30.000000 time steps
#
# Episode = 12
# t = 0
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 13.779723
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 1
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 11.854173
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 2
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 11.854173
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 3
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 11.854173
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 4
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 10.424390
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 5
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 10.424390
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 6
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 10.424390
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 7
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 10.424390
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 8
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 10.778792
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 9
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 11.047697
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 10
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 11.358006
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 11
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 11.646062
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 12
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 3.140429
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 13
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 3.140429
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 14
# Action: 0
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 3.624727
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 12 finished after 14.000000 time steps
#
# Episode = 13
# t = 0
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 13.779723
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 1
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 13.890237
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 2
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 14.481080
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 3
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 14.613253
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 4
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 14.613253
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 5
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 14.613253
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 6
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 14.974100
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 7
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 14.974100
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 8
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 14.974100
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 9
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 15.139774
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 10
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 15.481238
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 11
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 15.733100
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 12
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 15.432273
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 13
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 15.432273
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 14
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 15.432273
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 15
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 15.432273
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 16
# Action: 1
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 3.809843
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 17
# Action: 1
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 3.809843
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 18
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 4.290794
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 19
# Action: 1
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 4.379000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 13 finished after 19.000000 time steps
#
# Episode = 14
# t = 0
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 16.153227
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 1
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 15.138629
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 2
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 16.279852
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 3
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 16.279852
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 4
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 16.425076
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 5
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 11.854173
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 6
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 11.854173
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 7
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 12.127580
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 8
# Action: 0
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 12.566942
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 9
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 16.279852
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 10
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 14.882388
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 11
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 11.943804
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 12
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 11.943804
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 13
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 11.943804
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 14
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 11.943804
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 15
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 12.206013
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 16
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 3.725099
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 17
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 3.725099
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 14 finished after 17.000000 time steps
#
# Episode = 15
# t = 0
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 13.102868
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 1
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 11.943804
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 2
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 13.102868
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 3
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 13.102868
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 4
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 13.537353
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 5
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 9.938260
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 6
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 12.739521
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 7
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 12.739521
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 8
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 13.175823
# Explore rate: 1.000000
# ...
# Explore rate: 0.170053
# Learning rate: 0.170053
# Streaks: 0
#
#
# Episode = 169
# t = 151
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 29.446259
# Explore rate: 0.170053
# Learning rate: 0.170053
# Streaks: 0
#
#
# Episode = 169
# t = 152
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 29.566238
# Explore rate: 0.170053
# Learning rate: 0.170053
# Streaks: 0
#
#
# Episode = 169
# t = 153
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 29.686013
# Explore rate: 0.170053
# Learning rate: 0.170053
# Streaks: 0
#
# Episode 169 finished after 153.000000 time steps
#
# Episode = 170
# t = 0
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.465941
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 1
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 88.581114
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 2
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.520440
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 3
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 88.590179
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 4
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.373167
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 5
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.373167
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 6
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.392641
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 7
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.392641
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 8
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.412082
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 9
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 88.863315
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 10
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.522470
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 11
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 88.825450
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 12
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.551231
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 13
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.551231
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 14
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.570407
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 15
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 88.573305
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 16
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.591933
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 17
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.591933
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 18
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.611041
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 19
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.611041
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 20
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.630116
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 21
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 88.798697
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 22
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 88.798697
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 23
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 83.115295
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 24
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 83.115295
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 25
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 83.143575
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 26
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 83.171808
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 27
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 83.199994
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 28
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 83.228132
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 29
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 83.228132
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 30
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 29.805585
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
#
# Episode = 170
# t = 31
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 29.805585
# Explore rate: 0.167491
# Learning rate: 0.167491
# Streaks: 0
#
# Episode 170 finished after 31.000000 time steps
#
# Episode = 171
# t = 0
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.605968
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 1
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 88.595533
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 2
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.638752
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 3
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 88.621401
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 4
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 85.587529
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 5
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 85.587529
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 6
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 85.587529
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 7
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 85.611302
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 8
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.692967
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 9
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.692967
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 10
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.711617
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 11
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 87.875058
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 12
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.609180
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 13
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.609180
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 14
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 88.014935
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 15
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.546621
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 16
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 88.121525
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 17
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.496097
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 18
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 88.202283
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 19
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.467094
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 20
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 88.264985
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 21
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.654658
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 22
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.654658
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 23
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.673372
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 24
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 88.621401
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 25
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.699169
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 26
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 86.158073
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 27
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.453113
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 28
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.453113
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 29
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.472159
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 30
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 88.347973
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 31
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.302862
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 32
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.302862
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 33
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.322156
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 34
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 88.652868
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 35
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.486773
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 36
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.486773
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 37
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.505763
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 38
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 88.359826
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 39
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.411506
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 40
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.411506
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 41
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.430620
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 42
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 88.644462
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 43
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.500558
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 44
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 86.555671
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 45
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.516723
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 46
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.516723
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 47
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.535664
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 48
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 88.387465
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 49
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.201936
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 50
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.201936
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 51
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.221396
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 52
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 88.639694
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 53
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.546164
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 54
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.546164
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 55
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 88.565057
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 56
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 77.705112
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 57
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.325354
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 58
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.325354
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 59
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.344610
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 60
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 88.643159
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 61
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 88.428640
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 62
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 88.626862
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 63
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 87.966914
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
#
#
# Episode = 171
# t = 64
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 86.898076
# Explore rate: 0.164944
# Learning rate: 0.164944
# Streaks: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b33899c802e6> in <module>()
#     138
#     139 if __name__ == "__main__":
# --> 140     simulate()
#
# <ipython-input-1-b33899c802e6> in simulate()
#      74             # Print data
#      75             if (DEBUG_MODE):
# ---> 76                 print("\nEpisode = %d" % episode)
#      77                 print("t = %d" % t)
#      78                 print("Action: %d" % action)
#
# /anaconda3/lib/python3.6/site-packages/ipykernel/iostream.py in write(self, string)
#     350             is_child = (not self._is_master_process())
#     351             # only touch the buffer in the IO thread to avoid races
# --> 352             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     353             if is_child:
#     354                 # newlines imply flush in subprocesses
#
# /anaconda3/lib/python3.6/site-packages/ipykernel/iostream.py in schedule(self, f)
#     184         """
#     185         if self.thread.is_alive():
# --> 186             event_id = os.urandom(16)
#     187             while event_id in self._events:
#     188                 event_id = os.urandom(16)
#
# KeyboardInterrupt:

# %%
a = env.action_space
a.
